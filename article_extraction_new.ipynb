# %%
# !python -m spacy download en 
import nltk
nltk.download('punkt')
# !pip install bs4
# !pip install wikipedia
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import spacy
from spacy import displacy
from collections import Counter
# import en_core_web_smimport 
import requests
from bs4 import BeautifulSoup
import re
import urllib.request
nlp = spacy.load('en_core_web_sm') 
from nltk.tag import StanfordNERTagger
from nltk.tokenize import word_tokenize
# import wikipediaapi
import bs4
import urllib.request as ureq
from bs4 import BeautifulSoup as sou
import wikipedia
import requests
import html.parser

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# x=""
# nlp = spacy.load("en_core_web_sm")
# doc = nlp(u"In South Asia, the Iron Age is taken to begin with the ironworking Painted Gray Ware culture and to end with the reign of Ashoka 3rd century BC. The use of the term Iron Age in the archaeology of South, East and Southeast Asia is more recent, and less common, than for western Eurasia; at least in China prehistory had ended before iron-working arrived, so the term is infrequently used. The Sahel Sudan region and Sub-Saharan Africa are outside of the three-age system, there being no Bronze Age, but the term Iron Age is sometimes used in reference to early cultures practicing ironworking such as the Nok culture of Nigeria.")
# stripped = re.sub('<[^<]+?>','',doc.text)
# docs=nlp(stripped)

# for chunk in docs.noun_chunks:
#     x=x+chunk.text+","
# print(x)

# %%
f = open("/content/drive/My Drive/Colab Notebooks/ncrte_history.txt", "rb")
text = f.read().decode(errors='replace')
print(text)
stripped = re.sub('<[^<]+?>',' ',text)
# print(stripped)
x=""
nlp = spacy.load("en_core_web_sm")
docs=nlp(stripped)


for chunk in docs.noun_chunks:
    x=x+chunk.text+","
print(x)
# Out:
# There are several things we can find out � what
# people ate, the kinds of clothes they wore, the
# houses in which they lived. We can find out about
# the lives of hunters, herders, farmers, rulers,
# merchants, priests, crafts persons, artists,
# musicians, and scientists. We can also find out
# about the games children played, the stories they
# heard, the plays they saw, the songs they sang.
# Where did people live?
# Find the river Narmada on Map 1 (page 2). People
# have lived along the banks of this river for several
# hundred thousand years. Some of the earliest
# people who lived here were skilled gatherers, �
# that is, people who gathered their food. They knew
# about the vast wealth of plants in the surrounding
# forests, and collected roots, fruits and other forest
# produce for their food. They also hunted animals.
# CHAPTER 1
# WHAT, WHERE, HOW AND WHEN?
#
# WHAT, WHERE, HOW
# AND WHEN?
#
#  2
# OUR PASTS�I
#
# Now find the Sulaiman and Kirthar hills to the
# ...

# %%
strg=x
list = strg.split(",")
li = []
set1={}
engurl=[]
def WikiLinks(list):
    for i in range(len(list)):
        strg1 = list[i]
        try:
            page_Title = wikipedia.page(strg1)
            strg2 = page_Title.title
            print(strg2)
            complete_url = wikipedia.page(strg2)
            strg3 =complete_url.url
            print("English web page:",strg3)
            my_url = strg3
            html = ureq.urlopen(my_url)
            soup = sou(html)
            if(len(soup.find_all(class_= 'interlanguage-link interwiki-te'))==0):
                print("Telugu webpage not found")
                engurl.append(strg2)
            else:  
                for li in soup.find_all(class_= 'interlanguage-link interwiki-te'):
                    telugulink = li.a.get('href')
                    print("Telugu web page:",telugulink)
        except Exception as e:
            print(e)
    print("engurl:",engurl)
#     print(len(set(engurl)))
    
list = strg.split(",")

WikiLinks(list)
set1=set(engurl)
# set1=set(list)
print(set1)
# print(len(set(list)))
# Out:
# Page id "senegal things" does not match any pages. Try another id!
# We
# English web page: https://en.wikipedia.org/wiki/We
# Telugu webpage not found
# /usr/local/lib/python3.6/dist-packages/wikipedia/wikipedia.py:389: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 389 of the file /usr/local/lib/python3.6/dist-packages/wikipedia/wikipedia.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   lis = BeautifulSoup(html).find_all('li')
# "What" may refer to:
# Five Ws
# WHAT (AM)
# The Whip and the Body
# Who's on First?
# Stone Cold Steve Austin
# What? (film)
# what.
# "What"
# Vava Voom
# The Soft Boys
# "What?" (song)
# Eye for an Eye
# ...

# %%
ans=""
for i in set1:
  ans=ans+i+","
list_words=ans.split(",")
# print(list_words)
for i in range(len(list_words)):
  word=list_words[i]
  try:
    page_Title = wikipedia.page(word)
    word_title = page_Title.title
    complete_url = wikipedia.page(word_title)
    word_url =complete_url.url
    print(word_url)
#     print(word_title)
  except Exception as e:
    print(e)
# Out:
# https://en.wikipedia.org/wiki/North_East_England
# https://en.wikipedia.org/wiki/Amarna_letters
# https://en.wikipedia.org/wiki/Hardcourt
# https://en.wikipedia.org/wiki/Big_Four_accounting_firms
# https://en.wikipedia.org/wiki/List_of_historians
# https://en.wikipedia.org/wiki/Garo_people
# https://en.wikipedia.org/wiki/New_Ways_Ministry
# https://en.wikipedia.org/wiki/Herder
# https://en.wikipedia.org/wiki/Merchant
# https://en.wikipedia.org/wiki/Framing_(social_sciences)
# https://en.wikipedia.org/wiki/List_of_American_Civil_War_battles
# https://en.wikipedia.org/wiki/Decipherment
# https://en.wikipedia.org/wiki/EPICS
# https://en.wikipedia.org/wiki/They
# https://en.wikipedia.org/wiki/Spirit
# https://en.wikipedia.org/wiki/%C3%8D
# https://en.wikipedia.org/wiki/Kandahar
# https://en.wikipedia.org/wiki/Army
# https://en.wikipedia.org/wiki/List_of_Latin_words_with_English_derivatives
# https://en.wikipedia.org/wiki/K%26L_Gates
# https://en.wikipedia.org/wiki/Rokurokubi
# ...

# %%
print(set1)
ans=str(set1)
strr=ans
list = strr.split(",")
li = []
set1={}
engurl=[]
def WikiLinks(list):
    for i in range(len(list)):
        str1 = list[i]
        try:
            page_Title = wikipedia.page(str1)
            str2 = page_Title.title
            print(str2)
            complete_url = wikipedia.page(str2)
            str3 =complete_url.url
            print("English web page:",str3)
            my_url = str3
            html = ureq.urlopen(my_url)
            soup = sou(html)
            if(len(soup.find_all(class_= 'interlanguage-link interwiki-te'))==0):
                print("Telugu webpage not found")
                engurl.append(str2)
            else:  
                for li in soup.find_all(class_= 'interlanguage-link interwiki-te'):
                    telugulink = li.a.get('href')
                    print("Telugu web page:",telugulink)
        except Exception as e:
            print(e)
#     print("engurl:",engurl)
#     print(len(set(engurl)))
    
list = strr.split(",")

WikiLinks(list)
# Out:
# {" 'Greece'", "'the earth'"}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-84-c67145d020ed> in <module>()
#       1 print(set1)
# ----> 2 ans=str(set1)
#       3 strr=ans
#       4 list = str.split(",")
#       5 li = []
#
# TypeError: 'str' object is not callable

# %%
for i in range(len(set1)):
  strn = wikipedia.page(i)
  newurl = strn.url
  print(strn,newurl)
  
  
  
  {'', 'Myanmar', 'smaller rivers', 'the earth', 'Greece', 'its tributary', 'the rest', 'An old silver coin', 'the information', 'the surface', 'artists', 'People', 'Jesus', 'some\r\nanswers', 'Egypt', 'different groups', 'the present', 'clues', 'merchants', 'a continent', 'caravans', 'a lion', 'the\r\nearliest cities', 'the orders', 'Christianity', 'both men', 'Differences', 'the Himalayas', 'subjects', 'the Greek', 'Nepal', 'the natural frontiers', 'Greek', 'three different languages', 'the north-east', 'the world', 'detectives', 'a charred form', 'Common Era', 'new and exciting places', 'Chapter', 'Archaeologists', 'OUR PASTS', 'herders', 'this area', 'Its rulers', 'the subcontinent', 'The name Bharata', 'skilled gatherers', 'a hard\r\nsurface', 'Narmada Valley', 'our pasts', 'bit', 'Return', 'stone', 'seeds', 'cloth', 'animals', 'the difficulties', 'The first cities', 'villages', 'the seas', 'a\r\nlittle frame', '3 \r\nagriculture', 'CHAPTER', 'contrast', 'the way', 'These years', 'livelihood', 'a\r\nscript', 'the founder', 'the Subcontinent', 'some people', 'the Vindhyas', 'Names', 'advice', 'we', 'a\r\nlarger river', 'the river Narmada', 'The Iranians', 'signs', 'K L', 'Ganga Valley', 'Lanka', 'Iran', 'the Andaman Islands', 'Magadha', 'China', 'Objects', 'bones', 'weapons', 'town', 'the specially prepared bark', 'victories', 'a\r\ncountry', 'her', '/him', 'dates', 'Rasheeda', 'at least two ways', 'several ways', 'our country', 'the surrounding\r\nforests', 'the country', 'What', 'Besides', '1\r\n\r\nPhysical Map', 'manuscript\r\ninscription', 'instruction', 'pieces', 'your atlas', 'many\r\n\r\nA page', 'two forms', 'customs', 'coins', 'a town', 'They', 'its tributaries', 'persons', 'historians', 'their food', 'religious teachers', 'the area', 'example', 'the sharing', 'other parts', 'buildings', 'the other areas', 'a great deal', 'This\r\ninscription', 'An old inscription', 'somebody', 'wood', 'O P', 'another kind', 'L', 'hunting', 'A pot', 'the coin', 'many other\r\nthings', 'Scripts', 'metal', 'what', 'the birth', 'the\r\nnorthwest', 'food', 'pans', 'sources', 'the\r\nneighbouring countries', 'Kirthar', 'all the objects', 'other inscriptions', 'present-day\r\nAfghanistan', 'rice', 'their\r\nlives', 'the vast wealth', 'the river', 'others', 'poems', 'Aramaic', 'an old\r\ncity', 'We', 'Magadha Hunting', 'WHAT', 'South Asia', 'sculpture', 'the north', 'the Egyptian letters', 'Afghanistan', 'an adventure', 'most countries', 'scripts', 'rulers', 'musicians', 'the south', 'the north coast', 'Rosetta', 'plays', 'the most famous stories', 'relatively hard surfaces', 'the letters BC', 'the day', 'this form', 'the games children', 'barley', 'records', 'the advantages', 'scientists', 'times', 'gatherers', 'Christ', 'today', 'the subjects', 'inscriptions', 'the letters', 'goat', '2000 years', 'You', 'scholars', 'two dates', 'Prakrit', 'floods', 'practices', 's', 'this book', 'Our Pasts', 'Trace', 'The first big kingdom', '� lands', 'the northwest', 'baked clay', 'several things', 'pages', 'the year', ' imperishable substances', 'the river Indus', 'the date', 'armies', 'medicine', 'Pots', 'music', 'a tree', 'supplies', '�', 'farmers', 'several hundreds', 'side', 'cattle', 'forest produce', 'these objects', 'women', 'they', 'A D', 'the\r\nIndus', 'These books', 'Garo hills Cities', '�s question', 'this river', 'Kandahar', 'bone', 'an inscribed\r\nstone', 'use', 'the Latin word', 'our cultural\r\ntraditions', 'Greek\r\n(top', 'hills', 'these frontiers', '(languages', 'religious beliefs', 'decipherment', 'a\r\nbirch bark manuscript', 'new ways', 'grain', 'what ways', 'source', 'difference', 'Historians', 'the Rigveda', '(page', 'at least\r\nfive different crafts', 'Bharat', 'an archaeologist', 'the north-\r\nwest', 'journeys', 'a ruler', 'the kinds', 'archaeology', 'the battles', 'deserts', 'Present�', 'one major difference', 'Asia', 'the names', 'Anno Domini�', 'the word source', 'it', 'time', 'the east', 'ordinary men', 'Bangladesh', 'Scholars', 'a palm leaf', 'the Ganga', 'their own food', 'these\r\nrivers', 'The hills', 'This inscription', 'different parts', 'CE', 'the title', 'the earliest\r\npeople', 'the present\r\ncountries', 'ships', 'the birch', 'Languages', 'a long time', 'crops', 'roots', 'plants', 'Indus', 'the Sulaiman', 'us', 'something', 'AD', 'him', 'most people', 'many manuscripts', 'the Garo', 'other forest', 'The palm', 'cities', 'science', 'clothes', 'I\r\n\r\nLetters', 'The places', 'BCE', 'letters', 'priests', 'the seacoasts', 'monasteries', 'different practices', 'people', 'both\r\nscripts', 'Pakistan', 'pots', 'who', 'This manuscript', 'our starting point', 'the words', 'the Indus', 'Map', 'them', 'Hills', 'years', 'The letters CE', 'central\r\nIndia', 'hand', 'historian', 'queens', 'archaeologists', 'the land', 'It', 'the years', 'manuscripts', 'the lives', 'Early agriculture', 'BP', 'the banks', 'fishing', 'writings', 'a large\r\nkingdom', 'All inscriptions', 'page', 'the crafts persons', 'a process', 'ordinary people', 'the mountains', 'seas', 'find tools', 'their\r\nvictories', 'fishing folk', 'crafts persons', 'the frontiers', 'paintings', 'year', 'north Africa', 'the\r\ndate', 'palm leaf', 'fruits', 'a bird', 'this one', 'all kinds', 'droughts', 'hunters', 'BC', 'attention', 'kings', 'a spirit', 'the\r\n\r\nearliest composition', 'books', 'a\r\nmap', 'the\r\nlives', 'other kinds', 'Egyptian', 'I', 'one part', 'two Latin words', 'the word', 'wheat', 'ornaments', 'battle', 'ancient times', 'village', 'Bhutan', 'A.', 'its\r\ntributaries', ' merchants', 'One past', 'five questions', 'Tamil', 'hard surfaces', 'the Greeks', 'natural\r\ndisasters', 'Sri', 'These movements', 'mountains', 'their orders', 'place', 'the\r\nhouses', 'the areas', 'men', 'the\r\npast', 'these\r\nobjects', '(tributaries', 'adventure', 'search', 'brick', 'Facing Page', 'sheep', 'temples', 'Common\r\nEra�', 'excavate', 'the Christian Era', 'two different scripts', 'ideas', 'the past', 'languages', 'month', 'these rivers', 'Kingdoms', 'the ones', 'epics', 'the sounds', 'hard', 'you', 'Sanskrit', 'anything', 'a language', 'Plant', 'the Lord', 'stands', 'a group', 'Coins', 'insects', 'valuable goods', 'these terms', 'a list', '(i.e. Christ', 'Locate', 'several\r\nhundred thousand years', 'India', 'all these\r\nsources', 'The word', 'the fact'}

# %%
str="South Asia,the Iron Age,the ironworking Painted Gray Ware culture,the reign,Ashoka 3rd century BC,The use,the term,Iron Age,the archaeology,South,East,Southeast,Asia,western Eurasia,China,prehistory,iron-working,the term,The Sahel Sudan region,Sub-Saharan Africa,the three-age system,no Bronze Age,the term,Iron Age,reference,early cultures,the Nok culture,Nigeria,"
list = str.split(",")
li = []
engurl=[]
def WikiLinks(list):
    for i in range(len(list)):
        str1 = list[i]
        try:
            page_Title = wikipedia.page(str1)
            str2 = page_Title.title
            print(str2)
            complete_url = wikipedia.page(str2)
            str3 =complete_url.url
            print("English web page:",str3)
            my_url = str3
            html = ureq.urlopen(my_url)
            soup = sou(html)
            if(len(soup.find_all(class_= 'interlanguage-link interwiki-te'))==0):
                print("Telugu webpage not found")
                engurl.append(str2)
            else:  
                for li in soup.find_all(class_= 'interlanguage-link interwiki-te'):
                    telugulink = li.a.get('href')
                    print("Telugu web page:",telugulink)
        except Exception as e:
            print(e)
    print("engurl:",engurl)
    
list = str.split(",")

WikiLinks(list)

# %%
engurl: ['Iron Age', 'Iron Age', '3rd century BC', 'Iron Age', 'Points of the compass', 'Prehistory', 'Sahel', 'Sub-Saharan Africa', 'Three-age system', 'Bronze Age', 'Iron Age', 'Reference', 'History of science in early cultures', 'Nok culture']

# %%
# paragraph_text = ""
# for i in range(1,len(l2)):
#     w = urllib.request.urlopen(l2[i])
#     html = w.read()
#     temp2 = BeautifulSoup(html)
#     id = l2[i].split("/")[-1].split(".")[0].split("e")[1]
#     b = temp2.find("div", attrs={'id':'content-body-14269002-'+id})
#     print(b)
#     print("*******************")
#     for i in b.find_all("p"):
#         paragraph_text = i.text
# #     print(paragraph_text)
#     doc = nlp(paragraph_text)
#     print(doc.ents)
# #     print([(X.text, X.label_) for X in doc.ents])
#     print("-----------------------------------------------------------------------")

# %%
r1 = requests.get('https://en.wikipedia.org/wiki/History_of_science#Modern_science')
# r2 = requests.get('https://www.thehindu.com/news/national/telangana/feeder/default.rss')
# print(r.text)
stripped1 = re.sub('<[^<]+?>', '', r1.text)
# stripped2 = re.sub('<[^<]+?>','',r2.text)
soup1 = BeautifulSoup(stripped1)
# soup2 = BeautifulSoup(stripped2)

# %%
# l1 = []
# for link in soup1.find_all('p'):
#     temp1 = link.text.split(" ")
# for i in temp1:
#     if(i.startswith("http")):
#         print(i)
#         l1.append(i)

# %%
# l2 = []
# for link in soup2.find_all('p'):
#     temp2 = link.text.split(" ")
# for i in temp2:
#     if(i.startswith("http")):
#         print(i)
#         l2.append(i)

# %%
paragraph_text="The history of science is the study of the development of science and scientific knowledge, including both the natural and social sciences (the history of the arts and humanities is termed history of scholarship). Science is a body of empirical, theoretical, and practical knowledge about the natural world, produced by scientists who emphasize the observation, explanation, and prediction of real-world phenomena. Historiography of science, in contrast, studies the methods employed by historians of science.The English word scientist is relatively recent—first coined by William Whewell in the 19th century.[1] Previously, investigators of nature called themselves natural philosophers. While empirical investigations of the natural world have been described since classical antiquity (for example, by Thales and Aristotle), and the scientific method has been employed since the Middle Ages (for example, by Ibn al-Haytham and Roger Bacon), modern science began to develop in the early modern period, and in particular in the scientific revolution of 16th- and 17th-century Europe.[2] Traditionally, historians of science have defined science sufficiently broadly to include those earlier inquiries.[3]"
# for i in range(1,len(l1)):
#     w = urllib.request.urlopen(l1[i])
#     html = w.read()
#     temp1 = BeautifulSoup(html)
#     id = l1[i].split("/")[-1].split(".")[0].split("e")[1]
#     b = temp1.find("div", attrs={'id':'content-body-14269002-'+id})
#     print(b)
#     print("*******************")
#     for i in b.find_all("p"):
#         paragraph_text = i.text
# #     print(paragraph_text)
doc = nlp(paragraph_text)
print(doc.ents)
#     print([(X.text, X.label_) for X in doc.ents])
# print("-----------------------------------------------------------------------")
# Out:
# (Science, English, William Whewell, 19th, Thales, Aristotle, the Middle Ages, Ibn al-Haytham, Roger Bacon, 17th-century)
